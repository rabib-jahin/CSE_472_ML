# %%
# !git clone https://github.com/rabib-jahin/CSE_472_ML.git
# %cd CSE_472_ML
# !pip install gradio==3.14
# !pip install diffusers==0.14.0 xformers transformers scipy ftfy accelerate controlnet_aux
# !pip install -q opencv-contrib-python
# !wget https://www.dropbox.com/s/5jencqq4h59fbtb/FT_Epoch_latest.pt
# Out:
# Cloning into 'UnpromptedControl'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 221 (delta 0), reused 0 (delta 0), pack-reused 220
# Receiving objects: 100% (221/221), 6.64 MiB | 28.92 MiB/s, done.
# Resolving deltas: 100% (94/94), done.
# /content/UnpromptedControl/UnpromptedControl
# ERROR: Operation cancelled by user
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
# ...

# %%
gradioLink = "restore.py"


if gradioLink != "":
   # !python {gradioLink}
# Out:
# 2024-02-21 07:15:49.173542: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-21 07:15:49.173605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-21 07:15:49.178487: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-21 07:15:52.095748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Fetching 13 files: 100% 13/13 [00:00<00:00, 50300.69it/s]
# Running on local URL:  http://127.0.0.1:7860
#
# ...
